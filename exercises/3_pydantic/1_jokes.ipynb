# %% [markdown]
# ## 1. Validate data from API using Pydantic
#
# Use this code snippet to get a random dad joke
#
# ```py
# import requests
#
# headers = {"Accept": "application/json"}
# response = requests.get("https://icanhazdadjoke.com/", headers=headers)
#
# print(response.json())
# ```

# %%
import requests

headers = {"Accept": "application/json"}
response = requests.get("https://icanhazdadjoke.com/", headers=headers)

print(response.json())
# Out:
# {'id': 'QnWnWSfiqc', 'joke': "Why can't a bicycle stand on its own? It's two-tired.", 'status': 200}

# %% [markdown]
# a) Create a Pydantic model with name Joke with the following fields
#
# - id with type integer
# - joke with type string

# %%
from pydantic import BaseModel

class Joke(BaseModel):
    id: str
    joke: str

# %% [markdown]
# b) Validate the data from the API using the Joke model. Test out your Joke instance to see that you can access the joke and id fields.

# %%
joke = Joke.model_validate(response.json())
joke.joke
# Out:
# "Why can't a bicycle stand on its own? It's two-tired."

# %% [markdown]
# c) Now create a new Joke Pydantic model that also have the field words_in_joke. This is a computed field and a property so you will need to decorate your method like this
#
# ```py
#     @computed_field
#     @property
#     def words_in_joke(self) -> int:
#         """returns number of words in the joke"""
# ```
#
# Note that computed_field is imported from pydantic. Validate a random joke with your new Joke model.

# %%
from pydantic import computed_field

class Joke(BaseModel):
    id: str
    joke: str

    @computed_field
    @property
    def words_in_joke(self) -> int:
        """returns number of words in the joke"""
        return len(self.joke.split())

joke2 = Joke.model_validate(response.json())
joke2.joke, joke2.words_in_joke
# Out:
# ("Why can't a bicycle stand on its own? It's two-tired.", 10)

# %% [markdown]
# d) Request 10 jokes from the api and validate them into many Jokes instances that you store into a list. Make sure to use sleep for 5 seconds to not request from the API too much.

# %%
from time import sleep
jokes = []

headers = {"Accept": "application/json"}

for _ in range(0,10):
    response = requests.get("https://icanhazdadjoke.com/", headers=headers)
    jokes.append(Joke.model_validate(response.json()))
    sleep(5)

jokes
# Out:
# [Joke(id='LuciNmbaMmb', joke='What did the digital clock say to the grandfather clock? Look, no hands!', words_in_joke=13),
#  Joke(id='eNuHJBQCdFd', joke='How do you organize a space party? You planet.', words_in_joke=9),
#  Joke(id='IYT082EQukb', joke='Why was ten scared of seven? Because seven ate nine.', words_in_joke=10),
#  Joke(id='xkGB5oWSKmb', joke='Did you hear about the new restaurant on the moon? The food is great, but there’s just no atmosphere.', words_in_joke=19),
#  Joke(id='fqOmr4MeaFd', joke='What has a bed that you can’t sleep in? A river.', words_in_joke=11),
#  Joke(id='TCY0LmGQnb', joke='Why did the opera singer go sailing? They wanted to hit the high Cs.', words_in_joke=14),
#  Joke(id='6MR79MJ6h', joke='My boss told me to have a good day... so I went home.', words_in_joke=13),
#  Joke(id='69xAsrHYDAd', joke='Why did Mozart kill all his chickens?\r\nBecause when he asked them who the best composer was, they\'d all say "Bach bach bach!"\r\n', words_in_joke=22),
#  Joke(id='c2LJR7Ed2ob', joke='An apple a day keeps the bullies away. If you throw it hard enough.', words_in_joke=14),
#  Joke(id='wHlOu4o41g', joke='If you think swimming with dolphins is expensive, you should try swimming with sharks--it cost me an arm and a leg!', words_in_joke=21)]

# %%
for i,joke in enumerate(jokes):
    print(f"Joke {i+1}: {joke.joke} \nWords in joke: {joke.words_in_joke}\n")
# Out:
# Joke 1: What did the digital clock say to the grandfather clock? Look, no hands!
# Words in joke: 13
#
# Joke 2: How do you organize a space party? You planet.
# Words in joke: 9
#
# Joke 3: Why was ten scared of seven? Because seven ate nine.
# Words in joke: 10
#
# Joke 4: Did you hear about the new restaurant on the moon? The food is great, but there’s just no atmosphere.
# Words in joke: 19
#
# Joke 5: What has a bed that you can’t sleep in? A river.
# Words in joke: 11
#
# Joke 6: Why did the opera singer go sailing? They wanted to hit the high Cs.
# Words in joke: 14
#
# Joke 7: My boss told me to have a good day... so I went home.
# Words in joke: 13
#
# Joke 8: Why did Mozart kill all his chickens?
# Because when he asked them who the best composer was, they'd all say "Bach bach bach!"
#
# Words in joke: 22
#
# Joke 9: An apple a day keeps the bullies away. If you throw it hard enough.
# Words in joke: 14
#
# Joke 10: If you think swimming with dolphins is expensive, you should try swimming with sharks--it cost me an arm and a leg!
# Words in joke: 21
