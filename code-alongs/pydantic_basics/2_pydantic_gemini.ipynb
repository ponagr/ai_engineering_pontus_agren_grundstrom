# %% [markdown]
# # Pydantic with gemini

# %%
from dotenv import load_dotenv 
from google import genai
import os 

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# It learns from data to recognize patterns and make decisions.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""You are a helpful assistant. I need you to create a JSON object representing a library. 
    The library's name should be 'Coolu Libraru' and have the fields name and books that contains a list of book. 
    Each book should have a 'title', 'author', and 'year' field. Make sure the output is a single, valid JSON object. Give me 10 books. 
    Remove ```json and ``` """,
)

response.text
# Out:
# '{\n  "name": "Coolu Libraru",\n  "books": [\n    {\n      "title": "The Quantum Realm",\n      "author": "Dr. Elara Vance",\n      "year": 2018\n    },\n    {\n      "title": "Whispers of the Forgotten Star",\n      "author": "Seraphina Moon",\n      "year": 1995\n    },\n    {\n      "title": "Chronicles of the Azure City",\n      "author": "Kaelen Stone",\n      "year": 2007\n    },\n    {\n      "title": "The Silent Cartographer",\n      "author": "Lydia Thorne",\n      "year": 1982\n    },\n    {\n      "title": "Echoes in the Digital Wind",\n      "author": "Jaxson Byte",\n      "year": 2021\n    },\n    {\n      "title": "Beneath the Obsidian Sky",\n      "author": "Anya Sharma",\n      "year": 1999\n    },\n    {\n      "title": "The Alchemist\'s Secret",\n      "author": "Professor Eldrin",\n      "year": 2003\n    },\n    {\n      "title": "Journey to the Sunken Peaks",\n      "author": "Maya Rivers",\n      "year": 2015\n    },\n    {\n      "title": "The Gilded Cage of Time",\n      "author": "Silas Thorne",\n      "year": 1976\n    },\n    {\n      "title": "Patterns of Reality",\n      "author": "Dr. Viviana Reed",\n      "year": 2023\n    }\n  ]\n}'

# %%
print(response.text)
# Out:
# {
#   "name": "Coolu Libraru",
#   "books": [
#     {
#       "title": "The Quantum Realm",
#       "author": "Dr. Elara Vance",
#       "year": 2018
#     },
#     {
#       "title": "Whispers of the Forgotten Star",
#       "author": "Seraphina Moon",
#       "year": 1995
#     },
#     {
#       "title": "Chronicles of the Azure City",
#       "author": "Kaelen Stone",
#       "year": 2007
#     },
#     {
#       "title": "The Silent Cartographer",
#       "author": "Lydia Thorne",
#       "year": 1982
#     },
#     {
#       "title": "Echoes in the Digital Wind",
#       "author": "Jaxson Byte",
#       "year": 2021
#     },
#     {
#       "title": "Beneath the Obsidian Sky",
#       "author": "Anya Sharma",
#       "year": 1999
#     },
#     {
#       "title": "The Alchemist's Secret",
#       "author": "Professor Eldrin",
#       "year": 2003
#     },
#     {
#       "title": "Journey to the Sunken Peaks",
#       "author": "Maya Rivers",
#       "year": 2015
#     },
#     {
#       "title": "The Gilded Cage of Time",
#       "author": "Silas Thorne",
#       "year": 1976
#     },
#     {
#       "title": "Patterns of Reality",
#       "author": "Dr. Viviana Reed",
#       "year": 2023
#     }
#   ]
# }

# %%
from pydantic import BaseModel, Field 
from typing import List
from datetime import datetime

class Book(BaseModel):
    title: str 
    author: str 
    year: int = Field(gt = 1000, lt = datetime.now().year)

class Library(BaseModel):
    name: str 
    books: List[Book]


library = Library.model_validate_json(response.text)
library
# Out:
# Library(name='Coolu Libraru', books=[Book(title='The Quantum Realm', author='Dr. Elara Vance', year=2018), Book(title='Whispers of the Forgotten Star', author='Seraphina Moon', year=1995), Book(title='Chronicles of the Azure City', author='Kaelen Stone', year=2007), Book(title='The Silent Cartographer', author='Lydia Thorne', year=1982), Book(title='Echoes in the Digital Wind', author='Jaxson Byte', year=2021), Book(title='Beneath the Obsidian Sky', author='Anya Sharma', year=1999), Book(title="The Alchemist's Secret", author='Professor Eldrin', year=2003), Book(title='Journey to the Sunken Peaks', author='Maya Rivers', year=2015), Book(title='The Gilded Cage of Time', author='Silas Thorne', year=1976), Book(title='Patterns of Reality', author='Dr. Viviana Reed', year=2023)])

# %%
library.__dict__
# Out:
# {'name': 'Coolu Libraru',
#  'books': [Book(title='The Quantum Realm', author='Dr. Elara Vance', year=2018),
#   Book(title='Whispers of the Forgotten Star', author='Seraphina Moon', year=1995),
#   Book(title='Chronicles of the Azure City', author='Kaelen Stone', year=2007),
#   Book(title='The Silent Cartographer', author='Lydia Thorne', year=1982),
#   Book(title='Echoes in the Digital Wind', author='Jaxson Byte', year=2021),
#   Book(title='Beneath the Obsidian Sky', author='Anya Sharma', year=1999),
#   Book(title="The Alchemist's Secret", author='Professor Eldrin', year=2003),
#   Book(title='Journey to the Sunken Peaks', author='Maya Rivers', year=2015),
#   Book(title='The Gilded Cage of Time', author='Silas Thorne', year=1976),
#   Book(title='Patterns of Reality', author='Dr. Viviana Reed', year=2023)]}

# %%
type(library)
# Out:
# __main__.Library

# %%
isinstance(library, BaseModel)
# Out:
# True

# %%
library.name
# Out:
# 'Coolu Libraru'

# %%
library.books
# Out:
# [Book(title='The Quantum Realm', author='Dr. Elara Vance', year=2018),
#  Book(title='Whispers of the Forgotten Star', author='Seraphina Moon', year=1995),
#  Book(title='Chronicles of the Azure City', author='Kaelen Stone', year=2007),
#  Book(title='The Silent Cartographer', author='Lydia Thorne', year=1982),
#  Book(title='Echoes in the Digital Wind', author='Jaxson Byte', year=2021),
#  Book(title='Beneath the Obsidian Sky', author='Anya Sharma', year=1999),
#  Book(title="The Alchemist's Secret", author='Professor Eldrin', year=2003),
#  Book(title='Journey to the Sunken Peaks', author='Maya Rivers', year=2015),
#  Book(title='The Gilded Cage of Time', author='Silas Thorne', year=1976),
#  Book(title='Patterns of Reality', author='Dr. Viviana Reed', year=2023)]

# %% [markdown]
# extract titles into a list

# %%
titles = [book.title for book in library.books]
titles
# Out:
# ['The Quantum Realm',
#  'Whispers of the Forgotten Star',
#  'Chronicles of the Azure City',
#  'The Silent Cartographer',
#  'Echoes in the Digital Wind',
#  'Beneath the Obsidian Sky',
#  "The Alchemist's Secret",
#  'Journey to the Sunken Peaks',
#  'The Gilded Cage of Time',
#  'Patterns of Reality']

# %% [markdown]
# extract titles with books after certain year

# %%
newer_books = [(book.title, book.year) for book in library.books if book.year > 1950]
newer_books
# Out:
# [('The Quantum Realm', 2018),
#  ('Whispers of the Forgotten Star', 1995),
#  ('Chronicles of the Azure City', 2007),
#  ('The Silent Cartographer', 1982),
#  ('Echoes in the Digital Wind', 2021),
#  ('Beneath the Obsidian Sky', 1999),
#  ("The Alchemist's Secret", 2003),
#  ('Journey to the Sunken Peaks', 2015),
#  ('The Gilded Cage of Time', 1976),
#  ('Patterns of Reality', 2023)]

# %% [markdown]
# to get back json data use model_dump()

# %%
library.model_dump()
# Out:
# {'name': 'Coolu Libraru',
#  'books': [{'title': 'The Quantum Realm',
#    'author': 'Dr. Elara Vance',
#    'year': 2018},
#   {'title': 'Whispers of the Forgotten Star',
#    'author': 'Seraphina Moon',
#    'year': 1995},
#   {'title': 'Chronicles of the Azure City',
#    'author': 'Kaelen Stone',
#    'year': 2007},
#   {'title': 'The Silent Cartographer', 'author': 'Lydia Thorne', 'year': 1982},
#   {'title': 'Echoes in the Digital Wind',
#    'author': 'Jaxson Byte',
#    'year': 2021},
#   {'title': 'Beneath the Obsidian Sky', 'author': 'Anya Sharma', 'year': 1999},
#   {'title': "The Alchemist's Secret",
#    'author': 'Professor Eldrin',
#    'year': 2003},
#   {'title': 'Journey to the Sunken Peaks',
#    'author': 'Maya Rivers',
#    'year': 2015},
#   {'title': 'The Gilded Cage of Time', 'author': 'Silas Thorne', 'year': 1976},
#   {'title': 'Patterns of Reality',
#    'author': 'Dr. Viviana Reed',
#    'year': 2023}]}

# %% [markdown]
# output json file

# %%
with open("library.json", "w") as json_file:
    json_file.write(library.model_dump_json())

# %% [markdown]
# create pandas dataframe

# %%
import pandas as pd 

titles = [book.title for book in library.books]
years = [book.year for book in library.books]
authors = [book.author for book in library.books]

pd.DataFrame({"title": titles, "year": years, "author": authors})
# Out:
#                             title  year            author
# 0               The Quantum Realm  2018   Dr. Elara Vance
# 1  Whispers of the Forgotten Star  1995    Seraphina Moon
# 2    Chronicles of the Azure City  2007      Kaelen Stone
# 3         The Silent Cartographer  1982      Lydia Thorne
# 4      Echoes in the Digital Wind  2021       Jaxson Byte
# 5        Beneath the Obsidian Sky  1999       Anya Sharma
# 6          The Alchemist's Secret  2003  Professor Eldrin
# 7     Journey to the Sunken Peaks  2015       Maya Rivers
# 8         The Gilded Cage of Time  1976      Silas Thorne
# 9             Patterns of Reality  2023  Dr. Viviana Reed
