# %% [markdown]
# bild = pixlar = siffror i matriser = np.array i python
#
# svartvitt = 2 dimensioner
# 2d matris
# 0 = svart, 1 = vit
# 1 1 1
# 1 0 1
# 0 0 0
#
# size: (3,3)
#
# 0.2 gråskala mer mot svart osv
#
# varje element i matrisen motsvarar en pixelintensitet
# elementets position representerar vart pixeln finns på en skärm
#
# färgbild = 3 dimensioner
# 3d matris -> tensor
# samma som svartvitt, fast en till dimension som motsvarar röd, grön, blå och dess intensitet för att skapa en massa olika färgkombinationer
#
# size: (3,3,3)
#
# varje klammer([]) motsvarar en dimension
# np.array([[[]]]) = 3 dimensioner
# representerar tensorn
#
# ```py
# import matplotlib.image as mpimg
# import matplotlib.pyplot as plt
#
# img = mpimg.imread("bild.png")
#
# plt.imshow(img)
# ```

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("bild.png")

plt.imshow(img)
